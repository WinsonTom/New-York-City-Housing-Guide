# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans # Here is where you import the k-means algorithm from scikit-learn.
import pylab as pl # PyLab is a convenience module that bulk imports matplotlib.

# %%
# %matplotlib inline

# %%
DF = pd.read_csv(r'/Users/winsontom/Desktop/Career Foundry/Final CF Immersion/02 Data/5.0 w crime rate.csv')

# %%
DF.head(1)
# Out:
#                  Address    Borough Property Type  Bedrooms  Bathrooms  \
# 0  2 E 55th St Unit 803   Manhattan         Condo         2          2
#
#     Price  Square Footage  Price Per Square Feet  \
# 0  315000            1400                  225.0
#
#                                        Exact Address Neighborhood  \
# 0  Regis Residence, 2 E 55th St #803, New York, N...      Midtown
#
#             County  Zipcode                         Brokerage  \
# 0  New York County    10022   Douglas Elliman  -111 Fifth Ave
#
#    Violent Crime Rate
# 0                 NaN

# %%
pd.options.display.max_rows = None

# %%
DF['Neighborhood'].value_counts(dropna = False)
# Out:
# Neighborhood
# Flushing                389
# Upper East Side         283
# Jamaica                 193
# Upper West Side         191
# Great Kills             168
# Bensonhurst             101
# Sheepshead Bay           99
# Bayridge                 90
# Bergen Beach             90
# Bull's Head              81
# Forest Hills             78
# Murray Hill              76
# Midtown                  75
# Riverdale                75
# New York                 74
# Chelsea                  72
# Soundview Bruckner       62
# Brooklyn                 59
# Silver Lake              58
# East Village             58
# Grymes Hill              54
# Tribeca                  52
# Downtown Brooklyn        50
# South Slope              50
# Jackson Heights          49
# Homecrest                48
# Bayside                  46
# Meatpacking District     46
# East Harlem              45
# Rego Park                45
# Eastchester Bay          44
# East Flatbush            42
# ...

# %%
DF['Neighborhood Safety Rating'] = 'Values'

# %%
DF.head(1)
# Out:
#                  Address    Borough Property Type  Bedrooms  Bathrooms  \
# 0  2 E 55th St Unit 803   Manhattan         Condo         2          2
#
#     Price  Square Footage  Price Per Square Feet  \
# 0  315000            1400                  225.0
#
#                                        Exact Address Neighborhood  \
# 0  Regis Residence, 2 E 55th St #803, New York, N...      Midtown
#
#             County  Zipcode                         Brokerage  \
# 0  New York County    10022   Douglas Elliman  -111 Fifth Ave
#
#    Violent Crime Rate Neighborhood Safety Rating
# 0                 NaN                     Values

# %%
DF.loc[DF['Neighborhood'] == 'Flushing', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Upper East Side', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Jamaica', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Upper West Side', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Great Kills', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Bensonhurst', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Sheepshead Bay', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Bay Ridge', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Bergen Beach', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Bulls Head', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Forest Hills', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Murray Hill', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Midtown', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Riverdale', 'Neighborhood Safety Rating'] = 'B'

# %%
DF.loc[DF['Neighborhood'] == 'New York', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Chelsea', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Soundview Bruckner', 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Brooklyn', 'Neighborhood Safety Rating'] = 'N/A'

# %%
DF.loc[DF['Neighborhood'] == 'Silver Lake', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'East Village', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Grymes Hill', 'Neighborhood Safety Rating'] = 'A-'

# %%
DF.loc[DF['Neighborhood'] == 'Tribeca', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Downtown Brooklyn', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'South Slope', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Jackson Heights', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Homecrest', 'Neighborhood Safety Rating'] = 'N/A'

# %%
DF.loc[DF['Neighborhood'] == 'Bayside', 'Neighborhood Safety Rating'] = 'B+'

# %%
DF.loc[DF['Neighborhood'] == 'Meatpacking District', 'Neighborhood Safety Rating'] = 'A-'

# %%
DF.loc[DF['Neighborhood'] == 'East Harlem', 'Neighborhood Safety Rating'] = 'N/A'

# %%
DF.loc[DF['Neighborhood'] == 'Rego Park', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Eastchester Bay', 'Neighborhood Safety Rating'] = 'B'

# %%
DF.loc[DF['Neighborhood'] == 'East Flatbush', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Rosebank', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'City Line', 'Neighborhood Safety Rating'] = 'N/A'

# %%
DF.loc[DF['Neighborhood'] == 'Rossville', 'Neighborhood Safety Rating'] = 'B'

# %%
DF.loc[DF['Neighborhood'] == 'Sunset Park', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Washington Heights', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'East New York', 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Harlem', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Van Nest', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Elmhurst', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Long Island City', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Coney Island', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'West Brighton', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'North Baychester', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Canarsie', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Soho', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Pelham Gardens', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Westchester Square', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Williamsburg', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Astoria', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Totenville', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Soundview', 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Prospect Heights', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Mariners Park', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Morningside Heights', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Ocean Hills', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Howard Beach', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Dyker Heights', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Stuyvesant Park', 'Neighborhood Safety Rating'] = 'B'

# %%
DF.loc[DF['Neighborhood'] == 'Far Rockaway', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Bedford Stuyvesant', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Red Hook', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Marine Park', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Glen Oaks', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Melrose', 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Queens Village', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Chinatown', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Ridgewood', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Rockaway Park', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Van Cortlandt Pk', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Borough Park', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Hamilton Heights', 'Neighborhood Safety Rating'] = 'N/A'

# %%
DF.loc[DF['Neighborhood'] == 'Whitestone', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Woodside', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Kew Gardens', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Little Poland', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Prospect Leffert', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Belmont', 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Clinton', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Wakefields', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Brownsville', 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Boerum Hill', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Crown Heights', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Wall Street', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Flatbush', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'College Point', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Bathgate', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Corona', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Navy Hills', 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Bronx Park South', 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Douglaston', 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Inwood', 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Jerome Park', 'Neighborhood Safety Rating'] = 'N/A'

# %%
DF.loc[DF['Neighborhood'] == 'Morris Heights' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'East Elmhurst' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Highbridge' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Little Neck' , 'Neighborhood Safety Rating'] = 'B'

# %%
DF.loc[DF['Neighborhood'] == 'Queens' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'City Hall' , 'Neighborhood Safety Rating'] = 'B+'

# %%
DF.loc[DF['Neighborhood'] == 'Woodhaven' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Brooklyn Heights' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Governors Island' , 'Neighborhood Safety Rating'] = 'N/A'

# %%
DF.loc[DF['Neighborhood'] == 'Longwood' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Ozone Park' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Bronx' , 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Fresh Meadows' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Battery Park' , 'Neighborhood Safety Rating'] = 'B+'

# %%
DF.loc[DF['Neighborhood'] == 'Mott Haven' , 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Richmond Hill' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Arverne' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Middle Village' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'South Richmond Hill' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Maspeth' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Hollis' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Steinway' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'South Ozone Park' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Hunts Point' , 'Neighborhood Safety Rating'] = 'C-'

# %%
DF.loc[DF['Neighborhood'] == 'Malba' , 'Neighborhood Safety Rating'] = 'B+'

# %%
DF.loc[DF['Neighborhood'] == 'Roosevelt Island' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Breezy Point' , 'Neighborhood Safety Rating'] = 'A-'

# %%
DF.loc[DF['Neighborhood'] == 'St. Albans' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Rosedale' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Jamaica Hills' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Cambria Heights' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Beechhurst' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Addisleigh Park' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Bellerose' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Oakland Gardens' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Bayswater' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Parking lot' , 'Neighborhood Safety Rating'] = 'N/A'

# %%
DF.loc[DF['Neighborhood'] == 'Sunnyside' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Dumbo' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Clearview' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'PECK SLIP' , 'Neighborhood Safety Rating'] = 'B+'

# %%
DF.loc[DF['Neighborhood'] == 'Auburndale' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Laurelton' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Coop City' , 'Neighborhood Safety Rating'] = 'C'

# %%
DF.loc[DF['Neighborhood'] == 'Glendale' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Broad Channel' , 'Neighborhood Safety Rating'] = 'B-'

# %%
DF.loc[DF['Neighborhood'] == 'Queensboro Hill' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.head(100)
# Out:
#                                               Address        Borough  \
# 0                               2 E 55th St Unit 803       Manhattan
# 1   Central Park Tower Penthouse-217 W 57th  St Un...      Manhattan
# 2                                   620 Sinclair Ave   Staten Island
# 3                            2 E 55th St Unit 908W33       Manhattan
# 4                                        5 E 64th St       Manhattan
# 5                                        584 Park Pl        Brooklyn
# 6                             157 W 126th St Unit 1B       Manhattan
# 7                                    177 Benedict Rd   Staten Island
# 8                            875 Morrison Ave Apt 3M           Bronx
# 9                             1350 Ocean Pkwy Apt 5G        Brooklyn
# 10                       800 Grand Concourse Apt 2JS           Bronx
# 11                                  456 Van Name Ave   Staten Island
# 12                             34-41 85th St Unit 1D          Queens
# ...

# %%
DF.loc[DF['Neighborhood'] == 'Bayridge' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.loc[DF['Neighborhood'] == 'Brooklyn' , 'Neighborhood Safety Rating'] = 'C+'

# %%
DF.to_csv('r/Users/winsontom/Desktop/Career Foundry/Final CF Immersion/02 Data/6.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 DF.to_csv('r/Users/winsontom/Desktop/Career Foundry/Final CF Immersion/02 Data/6.0.csv')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
# ...
