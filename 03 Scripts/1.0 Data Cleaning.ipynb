# %%
import pandas as pd
import numpy as np
import os

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Loading Files

# %%
DF = pd.read_csv(r'/Users/winsontom/Desktop/Career Foundry/Final CF Immersion/02 Data/1.0 of data set.csv')

# %%
DF.shape
# Out:
# (4801, 17)

# %% [markdown]
# ## Dropping Duplicates (If there are any)

# %%
DF = DF.drop_duplicates()

# %%
#214 duplicate rows were dropped. DF had 4801, now it has 4587 after dropping duplicates
DF.shape
# Out:
# (4587, 17)

# %% [markdown]
# ## Dropping Columns that are unncessary

# %%
#View the column names
DF.columns
# Out:
# Index(['BROKERTITLE', 'TYPE', 'PRICE', 'BEDS', 'BATH', 'PROPERTYSQFT',
#        'ADDRESS', 'STATE', 'MAIN_ADDRESS', 'ADMINISTRATIVE_AREA_LEVEL_2',
#        'LOCALITY', 'SUBLOCALITY', 'STREET_NAME', 'LONG_NAME',
#        'FORMATTED_ADDRESS', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
#Latitude, Longitude, ADMINISTRATIVE_AREA_LEVEL_2 ,  not needed for our purpose. 
#Address column is also uncessary, we have the Main address and Formatted address that is more clear.
#Dropping the 4 columns discussed.

# %%
DF = DF.drop(columns=['LATITUDE'])

# %%
DF = DF.drop(columns=['LONGITUDE'])

# %%
DF = DF.drop(columns=['ADMINISTRATIVE_AREA_LEVEL_2'])

# %%
DF = DF.drop(columns=['ADDRESS'])

# %%
#Checking current DF columns
DF.head(5)
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT                    STATE  \
# 0     315000     2   2.000000        1400.0       New York, NY 10022
# 1  195000000     7  10.000000       17545.0       New York, NY 10019
# 2     260000     4   2.000000        2015.0  Staten Island, NY 10312
# 3      69000     3   1.000000         445.0      Manhattan, NY 10022
# 4   55000000     7   2.373861       14175.0       New York, NY 10065
#
#                                         MAIN_ADDRESS  LOCALITY  \
# 0             2 E 55th St Unit 803New York, NY 10022  New York
# 1  Central Park Tower Penthouse-217 W 57th New Yo...  New York
# 2            620 Sinclair AveStaten Island, NY 10312  New York
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022  New York
# 4                      5 E 64th StNew York, NY 10065  New York
#
#        SUBLOCALITY       STREET_NAME         LONG_NAME  \
# 0        Manhattan  East 55th Street   Regis Residence
# 1  New York County          New York  West 57th Street
# 2  Richmond County     Staten Island   Sinclair Avenue
# 3  New York County          New York  East 55th Street
# 4  New York County          New York  East 64th Street
#
#                                    FORMATTED_ADDRESS
# 0  Regis Residence, 2 E 55th St #803, New York, N...
# 1             217 W 57th St, New York, NY 10019, USA
# 2     620 Sinclair Ave, Staten Island, NY 10312, USA
# 3               2 E 55th St, New York, NY 10022, USA
# 4               5 E 64th St, New York, NY 10065, USA

# %% [markdown]
# ## Rename Columns

# %%
#Column names can be more clear

# %% [markdown]
# DF.rename(columns = {'PROPERTYSQFT' : 'Square Footage'}, inplace = True)

# %%
DF.rename(columns = {'MAIN_ADDRESS' : 'Address_1'}, inplace = True)

# %%
DF.rename(columns = {'STREET_NAME' : 'Neighborhood'}, inplace = True)

# %%
DF.rename(columns = {'LONG_NAME' : 'Long Name'}, inplace = True)

# %%
DF.rename(columns = {'FORMATTED_ADDRESS' : 'Cleaned_Address'}, inplace = True)

# %%
DF.rename(columns = {'LOCALITY' : 'County'}, inplace = True)

# %%
DF.rename(columns = {'BEDS' : 'Bedrooms'}, inplace = True)

# %%
DF.rename(columns = {'BATH' : 'Bathrooms'}, inplace = True)

# %%
DF['STATE'].value_counts(dropna = False)
# Out:
# STATE
# Brooklyn, NY 11235            99
# Brooklyn, NY 11209            91
# Forest Hills, NY 11375        88
# Brooklyn, NY 11234            87
# Staten Island, NY 10314       80
#                               ..
# Ny, NY 10017                   1
# Queens, NY 11427               1
# Queens, NY 11429               1
# Long Island City, NY 11109     1
# Ozone Park, NY 11416           1
# Name: count, Length: 308, dtype: int64

# %% [markdown]
# ## Cleaning Columns to condense information (STATE, BROKERTYPE, TYPE, Address_1)

# %%
#State column has too much detail. The goal is to just get the zipcode and neighborhood. We know its NY data
#BROKERTYPE , I don't want to see Brokered by ____ or the location. I simply want "Douglas Elliman"
#Type, I just want to see the property type. "Condo for sale" to "Condo"

# %%
DF.head(1)
# Out:
#                                    BROKERTITLE            TYPE   PRICE  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale  315000
#
#    Bedrooms  Bathrooms  PROPERTYSQFT               STATE  \
# 0         2        2.0        1400.0  New York, NY 10022
#
#                                 Address_1    County SUBLOCALITY  \
# 0  2 E 55th St Unit 803New York, NY 10022  New York   Manhattan
#
#        Neighborhood        Long Name  \
# 0  East 55th Street  Regis Residence
#
#                                      Cleaned_Address
# 0  Regis Residence, 2 E 55th St #803, New York, N...

# %% [markdown]
# ## State - Splitting STATE Column to "Neighborhood" and "State"

# %%
#State column, lets seperate the zipcode first. Make zipcode into a new column.
#We created 2 new columns. Neighborhood which shows where within NY. We don't need "NY" we know this data is NY only
#Zipcode which isolates the specific area it is in

#We can delelete State column later on.

DF[['Neighborhood','Zipcode']] = DF['STATE'].str.split('NY', n=1, expand=True)
DF
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  Bedrooms  Bathrooms  PROPERTYSQFT                    STATE  \
# 0        315000         2   2.000000   1400.000000       New York, NY 10022
# 1     195000000         7  10.000000  17545.000000       New York, NY 10019
# 2        260000         4   2.000000   2015.000000  Staten Island, NY 10312
# 3         69000         3   1.000000    445.000000      Manhattan, NY 10022
# 4      55000000         7   2.373861  14175.000000       New York, NY 10065
# ...         ...       ...        ...           ...                      ...
# 4796     599000         1   1.000000   2184.207862      Manhattan, NY 10075
# 4797     245000         1   1.000000   2184.207862      Rego Park, NY 11374
# 4798    1275000         1   1.000000   2184.207862       New York, NY 10011
# 4799     598125         2   1.000000    655.000000       Elmhurst, NY 11373
# 4800     349000         1   1.000000    750.000000       Brooklyn, NY 11224
#
#                                               Address_1           County  \
# 0                2 E 55th St Unit 803New York, NY 10022         New York
# 1     Central Park Tower Penthouse-217 W 57th New Yo...         New York
# 2               620 Sinclair AveStaten Island, NY 10312         New York
# 3            2 E 55th St Unit 908W33Manhattan, NY 10022         New York
# 4                         5 E 64th StNew York, NY 10065         New York
# ...                                                 ...              ...
# 4796            222 E 80th St Apt 3AManhattan, NY 10075  New York County
# 4797             97-40 62 Dr Unit LgRego Park, NY 11374         New York
# 4798        427 W 21st St Unit GardenNew York, NY 10011         New York
# 4799         91-23 Corona Ave Unit 4GElmhurst, NY 11373    Queens County
# 4800          460 Neptune Ave Apt 14OBrooklyn, NY 11224     Kings County
#
#           SUBLOCALITY     Neighborhood         Long Name  \
# 0           Manhattan       New York,    Regis Residence
# 1     New York County       New York,   West 57th Street
# 2     Richmond County  Staten Island,    Sinclair Avenue
# 3     New York County      Manhattan,   East 55th Street
# 4     New York County       New York,   East 64th Street
# ...               ...              ...               ...
# 4796         New York      Manhattan,                222
# 4797    Queens County      Rego Park,         62nd Drive
# 4798  New York County       New York,   West 21st Street
# 4799           Queens       Elmhurst,              91-23
# 4800         Brooklyn       Brooklyn,                460
#
#                                         Cleaned_Address Zipcode
# 0     Regis Residence, 2 E 55th St #803, New York, N...   10022
# 1                217 W 57th St, New York, NY 10019, USA   10019
# 2        620 Sinclair Ave, Staten Island, NY 10312, USA   10312
# 3                  2 E 55th St, New York, NY 10022, USA   10022
# 4                  5 E 64th St, New York, NY 10065, USA   10065
# ...                                                 ...     ...
# 4796         222 E 80th St #3a, New York, NY 10075, USA   10075
# 4797            97-40 62nd Dr, Rego Park, NY 11374, USA   11374
# 4798             427 W 21st St, New York, NY 10011, USA   10011
# 4799     91-23 Corona Ave. #4b, Flushing, NY 11373, USA   11373
# 4800      460 Neptune Ave #14a, Brooklyn, NY 11224, USA   11224
#
# [4587 rows x 14 columns]

# %%
#Removed the comma from Neighborhood.
DF['Neighborhood'] = DF['Neighborhood'].str.replace(',','')
DF
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  Bedrooms  Bathrooms  PROPERTYSQFT                    STATE  \
# 0        315000         2   2.000000   1400.000000       New York, NY 10022
# 1     195000000         7  10.000000  17545.000000       New York, NY 10019
# 2        260000         4   2.000000   2015.000000  Staten Island, NY 10312
# 3         69000         3   1.000000    445.000000      Manhattan, NY 10022
# 4      55000000         7   2.373861  14175.000000       New York, NY 10065
# ...         ...       ...        ...           ...                      ...
# 4796     599000         1   1.000000   2184.207862      Manhattan, NY 10075
# 4797     245000         1   1.000000   2184.207862      Rego Park, NY 11374
# 4798    1275000         1   1.000000   2184.207862       New York, NY 10011
# 4799     598125         2   1.000000    655.000000       Elmhurst, NY 11373
# 4800     349000         1   1.000000    750.000000       Brooklyn, NY 11224
#
#                                               Address_1           County  \
# 0                2 E 55th St Unit 803New York, NY 10022         New York
# 1     Central Park Tower Penthouse-217 W 57th New Yo...         New York
# 2               620 Sinclair AveStaten Island, NY 10312         New York
# 3            2 E 55th St Unit 908W33Manhattan, NY 10022         New York
# 4                         5 E 64th StNew York, NY 10065         New York
# ...                                                 ...              ...
# 4796            222 E 80th St Apt 3AManhattan, NY 10075  New York County
# 4797             97-40 62 Dr Unit LgRego Park, NY 11374         New York
# 4798        427 W 21st St Unit GardenNew York, NY 10011         New York
# 4799         91-23 Corona Ave Unit 4GElmhurst, NY 11373    Queens County
# 4800          460 Neptune Ave Apt 14OBrooklyn, NY 11224     Kings County
#
#           SUBLOCALITY    Neighborhood         Long Name  \
# 0           Manhattan       New York    Regis Residence
# 1     New York County       New York   West 57th Street
# 2     Richmond County  Staten Island    Sinclair Avenue
# 3     New York County      Manhattan   East 55th Street
# 4     New York County       New York   East 64th Street
# ...               ...             ...               ...
# 4796         New York      Manhattan                222
# 4797    Queens County      Rego Park         62nd Drive
# 4798  New York County       New York   West 21st Street
# 4799           Queens       Elmhurst              91-23
# 4800         Brooklyn       Brooklyn                460
#
#                                         Cleaned_Address Zipcode
# 0     Regis Residence, 2 E 55th St #803, New York, N...   10022
# 1                217 W 57th St, New York, NY 10019, USA   10019
# 2        620 Sinclair Ave, Staten Island, NY 10312, USA   10312
# 3                  2 E 55th St, New York, NY 10022, USA   10022
# 4                  5 E 64th St, New York, NY 10065, USA   10065
# ...                                                 ...     ...
# 4796         222 E 80th St #3a, New York, NY 10075, USA   10075
# 4797            97-40 62nd Dr, Rego Park, NY 11374, USA   11374
# 4798             427 W 21st St, New York, NY 10011, USA   10011
# 4799     91-23 Corona Ave. #4b, Flushing, NY 11373, USA   11373
# 4800      460 Neptune Ave #14a, Brooklyn, NY 11224, USA   11224
#
# [4587 rows x 14 columns]

# %%
DF = DF.drop(columns = ['STATE'])

# %%
DF.columns
# Out:
# Index(['BROKERTITLE', 'TYPE', 'PRICE', 'Bedrooms', 'Bathrooms', 'PROPERTYSQFT',
#        'Address_1', 'County', 'SUBLOCALITY', 'Neighborhood', 'Long Name',
#        'Cleaned_Address', 'Zipcode'],
#       dtype='object')

# %% [markdown]
# ## Type - Splitting TYPE column into "Property Type"

# %%
#We know properties are for sale, this doesn't tell us much about the property. 
# We want to know is it single family, condo, co-op, multi family, etc

# %%
DF[['Property Type','For Sale']]= DF['TYPE'].str.split('for sale', n=1, expand=True)
DF.head(1)
# Out:
#                                    BROKERTITLE            TYPE   PRICE  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  Condo for sale  315000
#
#    Bedrooms  Bathrooms  PROPERTYSQFT                               Address_1  \
# 0         2        2.0        1400.0  2 E 55th St Unit 803New York, NY 10022
#
#      County SUBLOCALITY Neighborhood        Long Name  \
# 0  New York   Manhattan    New York   Regis Residence
#
#                                      Cleaned_Address Zipcode Property Type  \
# 0  Regis Residence, 2 E 55th St #803, New York, N...   10022        Condo
#
#   For Sale
# 0

# %%
DF['Property Type'].value_counts(dropna = False)
# Out:
# Property Type
# Co-op                 1388
# House                  966
# Condo                  842
# Multi-family home      699
# Townhouse              288
# Pending                229
# Contingent              87
# Land                    47
# For sale                20
# Foreclosure             14
# Condop                   4
# Coming Soon              2
# Mobile house             1
# Name: count, dtype: int64

# %%
#Sucessfully created a column that details what type of property this is. Instead of having "Co-op for sale". 
#Now we delete For Sale column and Type as we already got the information we need

# %%
DF = DF.drop(columns = ['TYPE'])

# %%
DF = DF.drop(columns = ['For Sale'])

# %%
DF.head(1)
# Out:
#                                    BROKERTITLE   PRICE  Bedrooms  Bathrooms  \
# 0  Brokered by Douglas Elliman  -111 Fifth Ave  315000         2        2.0
#
#    PROPERTYSQFT                               Address_1    County SUBLOCALITY  \
# 0        1400.0  2 E 55th St Unit 803New York, NY 10022  New York   Manhattan
#
#   Neighborhood        Long Name  \
# 0    New York   Regis Residence
#
#                                      Cleaned_Address Zipcode Property Type
# 0  Regis Residence, 2 E 55th St #803, New York, N...   10022        Condo

# %% [markdown]
# ## BROKERTITLE - Split BROKERTITLE to just Brokerage

# %%
#Brokered by Douglas Elliman - 111 Fifth Ave is too detailed we know things are "Brokered by"
#The goal is to just get "Douglas Elliman"

# %%
DF['BROKERTITLE'].str.split('by',n=1, expand=True)
# Out:
#               0                                                  1
# 0     Brokered                     Douglas Elliman  -111 Fifth Ave
# 1     Brokered                                             Serhant
# 2     Brokered                                          Sowae Corp
# 3     Brokered                                             COMPASS
# 4     Brokered    Sotheby's International Realty - East Side Ma...
# ...         ...                                                ...
# 4796  Brokered                                             COMPASS
# 4797  Brokered                                 Mjr Real Estate Llc
# 4798  Brokered                   Douglas Elliman - 575 Madison Ave
# 4799  Brokered                         E Realty International Corp
# 4800  Brokered                              Nyc Realty Brokers Llc
#
# [4587 rows x 2 columns]

# %%
#Above shows how we want it, seperated into two columns
#one with the actual brokerage & Brokerage location (if specificed)
#Rename these columns first
#Then delete "0"

# %%
DF[['0','Brokerage']]= DF['BROKERTITLE'].str.split('by',n=1, expand=True)
DF
# Out:
#                                             BROKERTITLE      PRICE  Bedrooms  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave     315000         2
# 1                                   Brokered by Serhant  195000000         7
# 2                                Brokered by Sowae Corp     260000         4
# 3                                   Brokered by COMPASS      69000         3
# 4     Brokered by Sotheby's International Realty - E...   55000000         7
# ...                                                 ...        ...       ...
# 4796                                Brokered by COMPASS     599000         1
# 4797                    Brokered by Mjr Real Estate Llc     245000         1
# 4798      Brokered by Douglas Elliman - 575 Madison Ave    1275000         1
# 4799            Brokered by E Realty International Corp     598125         2
# 4800                 Brokered by Nyc Realty Brokers Llc     349000         1
#
#       Bathrooms  PROPERTYSQFT  \
# 0      2.000000   1400.000000
# 1     10.000000  17545.000000
# 2      2.000000   2015.000000
# 3      1.000000    445.000000
# 4      2.373861  14175.000000
# ...         ...           ...
# 4796   1.000000   2184.207862
# 4797   1.000000   2184.207862
# 4798   1.000000   2184.207862
# 4799   1.000000    655.000000
# 4800   1.000000    750.000000
#
#                                               Address_1           County  \
# 0                2 E 55th St Unit 803New York, NY 10022         New York
# 1     Central Park Tower Penthouse-217 W 57th New Yo...         New York
# 2               620 Sinclair AveStaten Island, NY 10312         New York
# 3            2 E 55th St Unit 908W33Manhattan, NY 10022         New York
# 4                         5 E 64th StNew York, NY 10065         New York
# ...                                                 ...              ...
# 4796            222 E 80th St Apt 3AManhattan, NY 10075  New York County
# 4797             97-40 62 Dr Unit LgRego Park, NY 11374         New York
# 4798        427 W 21st St Unit GardenNew York, NY 10011         New York
# 4799         91-23 Corona Ave Unit 4GElmhurst, NY 11373    Queens County
# 4800          460 Neptune Ave Apt 14OBrooklyn, NY 11224     Kings County
#
#           SUBLOCALITY    Neighborhood         Long Name  \
# 0           Manhattan       New York    Regis Residence
# 1     New York County       New York   West 57th Street
# 2     Richmond County  Staten Island    Sinclair Avenue
# 3     New York County      Manhattan   East 55th Street
# 4     New York County       New York   East 64th Street
# ...               ...             ...               ...
# 4796         New York      Manhattan                222
# 4797    Queens County      Rego Park         62nd Drive
# 4798  New York County       New York   West 21st Street
# 4799           Queens       Elmhurst              91-23
# 4800         Brooklyn       Brooklyn                460
#
#                                         Cleaned_Address Zipcode Property Type  \
# 0     Regis Residence, 2 E 55th St #803, New York, N...   10022        Condo
# 1                217 W 57th St, New York, NY 10019, USA   10019        Condo
# 2        620 Sinclair Ave, Staten Island, NY 10312, USA   10312        House
# 3                  2 E 55th St, New York, NY 10022, USA   10022        Condo
# 4                  5 E 64th St, New York, NY 10065, USA   10065    Townhouse
# ...                                                 ...     ...           ...
# 4796         222 E 80th St #3a, New York, NY 10075, USA   10075        Co-op
# 4797            97-40 62nd Dr, Rego Park, NY 11374, USA   11374        Co-op
# 4798             427 W 21st St, New York, NY 10011, USA   10011        Co-op
# 4799     91-23 Corona Ave. #4b, Flushing, NY 11373, USA   11373        Condo
# 4800      460 Neptune Ave #14a, Brooklyn, NY 11224, USA   11224        Co-op
#
#               0                                          Brokerage
# 0     Brokered                     Douglas Elliman  -111 Fifth Ave
# 1     Brokered                                             Serhant
# 2     Brokered                                          Sowae Corp
# 3     Brokered                                             COMPASS
# 4     Brokered    Sotheby's International Realty - East Side Ma...
# ...         ...                                                ...
# 4796  Brokered                                             COMPASS
# 4797  Brokered                                 Mjr Real Estate Llc
# 4798  Brokered                   Douglas Elliman - 575 Madison Ave
# 4799  Brokered                         E Realty International Corp
# 4800  Brokered                              Nyc Realty Brokers Llc
#
# [4587 rows x 15 columns]

# %%
DF = DF.drop(columns = ['0'])

# %%
DF = DF.drop(columns = ['BROKERTITLE'])

# %%
DF.columns
# Out:
# Index(['PRICE', 'Bedrooms', 'Bathrooms', 'PROPERTYSQFT', 'Address_1', 'County',
#        'SUBLOCALITY', 'Neighborhood', 'Long Name', 'Cleaned_Address',
#        'Zipcode', 'Property Type', 'Brokerage'],
#       dtype='object')

# %%
DF['Brokerage'].value_counts(dropna = False)
# Out:
# Brokerage
#  COMPASS                                      435
#  Douglas Elliman - 575 Madison Ave            109
#  Brown Harris Stevens                          93
#  Corcoran East Side                            86
#  RE MAX Edge                                   75
#                                              ...
#  Grandeur Realty, Inc.                          1
#  Eva Real Estate LLC                            1
#  Cruz Network The Bronx Realty                  1
#  Howard Hanna Coach Realtors - Floral Park      1
#  New York Way Real Estate Corp                  1
# Name: count, Length: 1036, dtype: int64

# %%
#We succesfully extracted only the brokerage information, deleted any additional unncessary info.

# %%
DF.head(10)
# Out:
#        PRICE  Bedrooms  Bathrooms  PROPERTYSQFT  \
# 0     315000         2   2.000000   1400.000000
# 1  195000000         7  10.000000  17545.000000
# 2     260000         4   2.000000   2015.000000
# 3      69000         3   1.000000    445.000000
# 4   55000000         7   2.373861  14175.000000
# 5     690000         5   2.000000   4004.000000
# 6     899500         2   2.000000   2184.207862
# 7   16800000         8  16.000000  33000.000000
# 8     265000         1   1.000000    750.000000
# 9     440000         2   1.000000    978.000000
#
#                                            Address_1           County  \
# 0             2 E 55th St Unit 803New York, NY 10022         New York
# 1  Central Park Tower Penthouse-217 W 57th New Yo...         New York
# 2            620 Sinclair AveStaten Island, NY 10312         New York
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022         New York
# 4                      5 E 64th StNew York, NY 10065         New York
# 5                      584 Park PlBrooklyn, NY 11238         New York
# 6           157 W 126th St Unit 1BNew York, NY 10027  New York County
# 7             177 Benedict RdStaten Island, NY 10304         New York
# 8             875 Morrison Ave Apt 3MBronx, NY 10473        The Bronx
# 9           1350 Ocean Pkwy Apt 5GBrooklyn, NY 11230     Kings County
#
#        SUBLOCALITY    Neighborhood         Long Name  \
# 0        Manhattan       New York    Regis Residence
# 1  New York County       New York   West 57th Street
# 2  Richmond County  Staten Island    Sinclair Avenue
# 3  New York County      Manhattan   East 55th Street
# 4  New York County       New York   East 64th Street
# 5     Kings County       Brooklyn         Park Place
# 6         New York       New York                157
# 7  Richmond County  Staten Island      Benedict Road
# 8       East Bronx          Bronx        Parking lot
# 9         Brooklyn       Brooklyn               1350
#
#                                      Cleaned_Address Zipcode Property Type  \
# 0  Regis Residence, 2 E 55th St #803, New York, N...   10022        Condo
# 1             217 W 57th St, New York, NY 10019, USA   10019        Condo
# 2     620 Sinclair Ave, Staten Island, NY 10312, USA   10312        House
# 3               2 E 55th St, New York, NY 10022, USA   10022        Condo
# 4               5 E 64th St, New York, NY 10065, USA   10065    Townhouse
# 5               584 Park Pl, Brooklyn, NY 11238, USA   11238        House
# 6        157 W 126th St #1b, New York, NY 10027, USA   10027        Condo
# 7      177 Benedict Rd, Staten Island, NY 10304, USA   10304        House
# 8  Parking lot, 875 Morrison Ave #3m, Bronx, NY 1...   10473        Co-op
# 9       1350 Ocean Pkwy #5g, Brooklyn, NY 11230, USA   11230        Co-op
#
#                                            Brokerage
# 0                    Douglas Elliman  -111 Fifth Ave
# 1                                            Serhant
# 2                                         Sowae Corp
# 3                                            COMPASS
# 4   Sotheby's International Realty - East Side Ma...
# 5                                         Sowae Corp
# 6                  Douglas Elliman - 575 Madison Ave
# 7                              Connie Profaci Realty
# 8                                 Pantiga Group Inc.
# 9                               CENTURY 21 MK Realty

# %% [markdown]
# ## Address_1 - Split to Address & City_State_Zipcode

# %%
#Address_1 has "75 Morrison Ave Apt 3MBronx, NY 10473"
#Instead it should be ...
#Address "75 Morrison Ave Apt 3B"
#City_State_Zipcode "Bronx, NY 10473"

# %%
#Seperated Addresses by Zipcode and not zipcode part
#Will come back to replace the "New York, NY", "Staten Island, NY"....
DF[['Address','Delete']]= DF['Address_1'].str.split('NY',n=1, expand=True)

# %%
DF = DF.drop(columns = ['Delete'])

# %%
DF.head(5)
# Out:
#        PRICE  Bedrooms  Bathrooms  PROPERTYSQFT  \
# 0     315000         2   2.000000        1400.0
# 1  195000000         7  10.000000       17545.0
# 2     260000         4   2.000000        2015.0
# 3      69000         3   1.000000         445.0
# 4   55000000         7   2.373861       14175.0
#
#                                            Address_1    County  \
# 0             2 E 55th St Unit 803New York, NY 10022  New York
# 1  Central Park Tower Penthouse-217 W 57th New Yo...  New York
# 2            620 Sinclair AveStaten Island, NY 10312  New York
# 3         2 E 55th St Unit 908W33Manhattan, NY 10022  New York
# 4                      5 E 64th StNew York, NY 10065  New York
#
#        SUBLOCALITY    Neighborhood         Long Name  \
# 0        Manhattan       New York    Regis Residence
# 1  New York County       New York   West 57th Street
# 2  Richmond County  Staten Island    Sinclair Avenue
# 3  New York County      Manhattan   East 55th Street
# 4  New York County       New York   East 64th Street
#
#                                      Cleaned_Address Zipcode Property Type  \
# 0  Regis Residence, 2 E 55th St #803, New York, N...   10022        Condo
# 1             217 W 57th St, New York, NY 10019, USA   10019        Condo
# 2     620 Sinclair Ave, Staten Island, NY 10312, USA   10312        House
# 3               2 E 55th St, New York, NY 10022, USA   10022        Condo
# 4               5 E 64th St, New York, NY 10065, USA   10065    Townhouse
#
#                                            Brokerage  \
# 0                    Douglas Elliman  -111 Fifth Ave
# 1                                            Serhant
# 2                                         Sowae Corp
# 3                                            COMPASS
# 4   Sotheby's International Realty - East Side Ma...
#
#                                              Address
# 0                     2 E 55th St Unit 803New York,
# 1  Central Park Tower Penthouse-217 W 57th New Yo...
# 2                    620 Sinclair AveStaten Island,
# 3                 2 E 55th St Unit 908W33Manhattan,
# 4                              5 E 64th StNew York,

# %%
#Problem still persist with "Address" having too much information. 
#We can strip anything with New York, Staten Island, Brooklyn, Bronx, Queens

# %%
DF['Address'] = DF['Address'].str.replace(',','')

# %%
DF['Address'] = DF['Address'].str.replace('New York','')

# %%
DF['Address'] = DF['Address'].str.replace('Brooklyn','')

# %%
DF['Address'] = DF['Address'].str.replace('Queens','')

# %%
DF['Address'] = DF['Address'].str.replace('Staten Island','')

# %%
DF['Address'] = DF['Address'].str.replace('Bronx','')

# %%
DF['Address'] = DF['Address'].str.replace('Manhattan','')

# %%
DF.head(1)
# Out:
#     PRICE  Bedrooms  Bathrooms  PROPERTYSQFT  \
# 0  315000         2        2.0        1400.0
#
#                                 Address_1    County SUBLOCALITY Neighborhood  \
# 0  2 E 55th St Unit 803New York, NY 10022  New York   Manhattan    New York
#
#          Long Name                                    Cleaned_Address Zipcode  \
# 0  Regis Residence  Regis Residence, 2 E 55th St #803, New York, N...   10022
#
#   Property Type                         Brokerage                Address
# 0        Condo    Douglas Elliman  -111 Fifth Ave  2 E 55th St Unit 803

# %%
DF['Address'] = DF['Address'].str.replace('Corona','')
DF['Address'] = DF['Address'].str.replace('Jackson Heights','')
DF['Address'] = DF['Address'].str.replace('Brownville','')
DF['Address'] = DF['Address'].str.replace('Forest Heights','')
DF['Address'] = DF['Address'].str.replace('Kew Gardens','')
DF['Address'] = DF['Address'].str.replace('Forest Hills','')
DF['Address'] = DF['Address'].str.replace('Elmhurst','')
DF['Address'] = DF['Address'].str.replace('Woodside','')
DF['Address'] = DF['Address'].str.replace('Howard Beach','')
DF['Address'] = DF['Address'].str.replace('Richmond Hill','')
DF['Address'] = DF['Address'].str.replace('Garden','')
DF['Address'] = DF['Address'].str.replace('Flushing','')
DF['Address'] = DF['Address'].str.replace('Brighton Beach','')
DF['Address'] = DF['Address'].str.replace('Bayside','')
DF['Address'] = DF['Address'].str.replace('Bedford Stuyvesant','')
DF['Address'] = DF['Address'].str.replace('East Elmhurst','')
DF['Address'] = DF['Address'].str.replace('Saint Albans','')
DF['Address'] = DF['Address'].str.replace('Jamaica','')
DF['Address'] = DF['Address'].str.replace('Howard Beach','')
DF['Address'] = DF['Address'].str.replace('Sprinfield Gardens','')
DF['Address'] = DF['Address'].str.replace('City','')
DF['Address'] = DF['Address'].str.replace('East Flatbush','')
DF['Address'] = DF['Address'].str.replace('Astoria','')
DF['Address'] = DF['Address'].str.replace('Fresh Meadows','')
DF['Address'] = DF['Address'].str.replace('Rego Park','')
DF['Address'] = DF['Address'].str.replace('Fresh Meadows','')
DF['Address'] = DF['Address'].str.replace('Kensington','')
DF['Address'] = DF['Address'].str.replace('Rockaway Park','')
DF['Address'] = DF['Address'].str.replace('Fresh Meadows','')
DF['Address'] = DF['Address'].str.replace('Townhouse','')
DF['Address'] = DF['Address'].str.replace('Whitestone','')
DF['Address'] = DF['Address'].str.replace('Douglaston','')
DF['Address'] = DF['Address'].str.replace('Ozone Park','')
DF['Address'] = DF['Address'].str.replace('Douglaston','')
DF['Address'] = DF['Address'].str.replace('Middle Village','')
DF['Address'] = DF['Address'].str.replace('Rosedale','')
DF['Address'] = DF['Address'].str.replace('Ny','')
DF['Address'] = DF['Address'].str.replace('South Ozone Park','')
DF['Address'] = DF['Address'].str.replace('Rockaway Park','')
DF['Address'] = DF['Address'].str.replace('Upper Village','')
DF['Address'] = DF['Address'].str.replace('Roosevelt Island','')
DF['Address'] = DF['Address'].str.replace('Middle Village','')
DF['Address'] = DF['Address'].str.replace('Far Rockaway','')
DF['Address'] = DF['Address'].str.replace('Crown Heights','')
DF['Address'] = DF['Address'].str.replace('Floral Park','')
DF['Address'] = DF['Address'].str.replace('Briarwood','')
DF['Address'] = DF['Address'].str.replace('Mill Basin','')
DF['Address'] = DF['Address'].str.replace('Cambria Heights','')
DF['Address'] = DF['Address'].str.replace('Far Rockaway','')
DF['Address'] = DF['Address'].str.replace('New Hyde Park','')
DF['Address'] = DF['Address'].str.replace('South Ozone Park','')
DF['Address'] = DF['Address'].str.replace('College Point','')
DF['Address'] = DF['Address'].str.replace('New Hyde Park','')
DF['Address'] = DF['Address'].str.replace('Townhourse','')
DF['Address'] = DF['Address'].str.replace('Hollis','')
DF['Address'] = DF['Address'].str.replace('Unit Townhouse','')
DF['Address'] = DF['Address'].str.replace('South Ozone Park','')
DF['Address'] = DF['Address'].str.replace('Woodhaven','')
DF['Address'] = DF['Address'].str.replace('Middle Village','')
DF['Address'] = DF['Address'].str.replace('Floral Park','')
DF['Address'] = DF['Address'].str.replace('Far Rockaway','')
DF['Address'] = DF['Address'].str.replace('Ridgewood','')
DF['Address'] = DF['Address'].str.replace('Whitestone','')
DF['Address'] = DF['Address'].str.replace('Long Island','')
DF['Address'] = DF['Address'].str.replace('Rosedale','')
DF['Address'] = DF['Address'].str.replace('Cambria Heights','')
DF['Address'] = DF['Address'].str.replace('College Point','')
DF['Address'] = DF['Address'].str.replace('Cambria Heights','')
DF['Address'] = DF['Address'].str.replace('Ridgewood','')
DF['Address'] = DF['Address'].str.replace('Rego park','')
DF['Address'] = DF['Address'].str.replace('Sunnyside','')
DF['Address'] = DF['Address'].str.replace('Floral Park','')
DF['Address'] = DF['Address'].str.replace('Little Neck','')
DF['Address'] = DF['Address'].str.replace('East','')
DF['Address'] = DF['Address'].str.replace('Stuyvesant Heights','')
DF['Address'] = DF['Address'].str.replace('Floral Park','')
DF['Address'] = DF['Address'].str.replace('Hills','')
DF['Address'] = DF['Address'].str.replace('Ridgewood','')
DF['Address'] = DF['Address'].str.replace('Rockaway Park','')
DF['Address'] = DF['Address'].str.replace('Mltfmly','')
DF['Address'] = DF['Address'].str.replace('Beechhurst','')
DF['Address'] = DF['Address'].str.replace('Averne','')
DF['Address'] = DF['Address'].str.replace('Townhouse','')
DF['Address'] = DF['Address'].str.replace('Crown Heights','')
DF['Address'] = DF['Address'].str.replace('Averne','')
DF['Address'] = DF['Address'].str.replace('Whitestone','')
DF['Address'] = DF['Address'].str.replace('Canarsie','')
DF['Address'] = DF['Address'].str.replace('Far Rockaway','')
DF['Address'] = DF['Address'].str.replace('Bellerose','')
DF['Address'] = DF['Address'].str.replace('Middle Village','')
DF['Address'] = DF['Address'].str.replace('Bellerose','')
DF['Address'] = DF['Address'].str.replace('Rockaway Park','')
DF['Address'] = DF['Address'].str.replace('Springfield s','')
DF['Address'] = DF['Address'].str.replace('Briarwood','')
DF['Address'] = DF['Address'].str.replace('Woodhave','')
DF['Address'] = DF['Address'].str.replace('Glen Oaks','')
DF['Address'] = DF['Address'].str.replace('Rosedale','')
DF['Address'] = DF['Address'].str.replace('South Ozone Park','')
DF['Address'] = DF['Address'].str.replace('Averne','')
DF['Address'] = DF['Address'].str.replace('Far Rockaway','')
DF['Address'] = DF['Address'].str.replace('Glen Oaks','')
DF['Address'] = DF['Address'].str.replace('Hollis','')
DF['Address'] = DF['Address'].str.replace('Kensington','')
DF['Address'] = DF['Address'].str.replace('Stuyvesant Heights','')
DF['Address'] = DF['Address'].str.replace('Crown Heights','')
DF['Address'] = DF['Address'].str.replace('Prospect Lefferts s','')
DF['Address'] = DF['Address'].str.replace('Rego Park','')
DF['Address'] = DF['Address'].str.replace('Woodhaven','')
DF['Address'] = DF['Address'].str.replace('Littleneck','')
DF['Address'] = DF['Address'].str.replace('Bellerose','')
DF['Address'] = DF['Address'].str.replace('Malba','')
DF['Address'] = DF['Address'].str.replace('Village','')

# %%
DF['Address'].value_counts(dropna = False)
# Out:
# Address
# 310-312 ide Ave                  2
# 6659-6675 Amboy Rd               2
# 104-14 37th Ave                  2
# 18 W 127th St                    2
# 2619 Shore Pkwy                  2
#                                 ..
# 150 W 51st St Apt 808            1
# 6535 Broadway Apt 3G             1
# 124-21 Flatlands Ave Unit 8B     1
# 18-50 211 St Unit 3D             1
# 460 Neptune Ave Apt 14O          1
# Name: count, Length: 4582, dtype: int64

# %%
#Very tedious and manual process, but all neighborhoods remain. ONLY the true "Address" remains
#We got what we needed out of "Address_1"

# %%
DF = DF.drop(columns = ['Address_1'])

# %%
DF.columns
# Out:
# Index(['PRICE', 'Bedrooms', 'Bathrooms', 'PROPERTYSQFT', 'County',
#        'SUBLOCALITY', 'Neighborhood', 'Long Name', 'Cleaned_Address',
#        'Zipcode', 'Property Type', 'Brokerage', 'Address'],
#       dtype='object')

# %% [markdown]
# ## As the inputs are cleaned up, we can name rename the columns

# %%
#As the inputs are cleaned up, we can name rename the columns

# %%
DF.rename(columns = {'PRICE' : 'Price'}, inplace = True)

# %%
DF.rename(columns = {'SUBLOCALITY' : 'Borough'}, inplace = True)

# %%
DF.rename(columns = {'PROPERTYSQFT' : 'Square Feet'}, inplace = True)

# %%
DF.columns
# Out:
# Index(['Price', 'Bedrooms', 'Bathrooms', 'Square Feet', 'County', 'Borough',
#        'Neighborhood', 'Long Name', 'Cleaned_Address', 'Zipcode',
#        'Property Type', 'Brokerage', 'Address'],
#       dtype='object')

# %%
DF
# Out:
#           Price  Bedrooms  Bathrooms   Square Feet           County  \
# 0        315000         2   2.000000   1400.000000         New York
# 1     195000000         7  10.000000  17545.000000         New York
# 2        260000         4   2.000000   2015.000000         New York
# 3         69000         3   1.000000    445.000000         New York
# 4      55000000         7   2.373861  14175.000000         New York
# ...         ...       ...        ...           ...              ...
# 4796     599000         1   1.000000   2184.207862  New York County
# 4797     245000         1   1.000000   2184.207862         New York
# 4798    1275000         1   1.000000   2184.207862         New York
# 4799     598125         2   1.000000    655.000000    Queens County
# 4800     349000         1   1.000000    750.000000     Kings County
#
#               Borough    Neighborhood         Long Name  \
# 0           Manhattan       New York    Regis Residence
# 1     New York County       New York   West 57th Street
# 2     Richmond County  Staten Island    Sinclair Avenue
# 3     New York County      Manhattan   East 55th Street
# 4     New York County       New York   East 64th Street
# ...               ...             ...               ...
# 4796         New York      Manhattan                222
# 4797    Queens County      Rego Park         62nd Drive
# 4798  New York County       New York   West 21st Street
# 4799           Queens       Elmhurst              91-23
# 4800         Brooklyn       Brooklyn                460
#
#                                         Cleaned_Address Zipcode Property Type  \
# 0     Regis Residence, 2 E 55th St #803, New York, N...   10022        Condo
# 1                217 W 57th St, New York, NY 10019, USA   10019        Condo
# 2        620 Sinclair Ave, Staten Island, NY 10312, USA   10312        House
# 3                  2 E 55th St, New York, NY 10022, USA   10022        Condo
# 4                  5 E 64th St, New York, NY 10065, USA   10065    Townhouse
# ...                                                 ...     ...           ...
# 4796         222 E 80th St #3a, New York, NY 10075, USA   10075        Co-op
# 4797            97-40 62nd Dr, Rego Park, NY 11374, USA   11374        Co-op
# 4798             427 W 21st St, New York, NY 10011, USA   10011        Co-op
# 4799     91-23 Corona Ave. #4b, Flushing, NY 11373, USA   11373        Condo
# 4800      460 Neptune Ave #14a, Brooklyn, NY 11224, USA   11224        Co-op
#
#                                               Brokerage  \
# 0                       Douglas Elliman  -111 Fifth Ave
# 1                                               Serhant
# 2                                            Sowae Corp
# 3                                               COMPASS
# 4      Sotheby's International Realty - East Side Ma...
# ...                                                 ...
# 4796                                            COMPASS
# 4797                                Mjr Real Estate Llc
# 4798                  Douglas Elliman - 575 Madison Ave
# 4799                        E Realty International Corp
# 4800                             Nyc Realty Brokers Llc
#
#                                                 Address
# 0                                 2 E 55th St Unit 803
# 1     Central Park Tower Penthouse-217 W 57th  St Un...
# 2                                     620 Sinclair Ave
# 3                              2 E 55th St Unit 908W33
# 4                                          5 E 64th St
# ...                                                 ...
# 4796                              222 E 80th St Apt 3A
# 4797                               97-40 62 Dr Unit Lg
# 4798                               427 W 21st St Unit
# 4799                                91-23  Ave Unit 4G
# 4800                           460 Neptune Ave Apt 14O
#
# [4587 rows x 13 columns]

# %% [markdown]
# ## Checking for Null Values , Missing Values,

# %%
DF.isnull().sum()
# Out:
# Price               0
# Bedrooms            0
# Bathrooms           0
# Square Feet         0
# County              0
# Borough             0
# Neighborhood        0
# Long Name           0
# Cleaned_Address     0
# Zipcode             0
# Property Type       0
# Brokerage          33
# Address             0
# dtype: int64

# %%
DF[DF['Brokerage'].isnull()==True]
# Out:
#         Price  Bedrooms  Bathrooms  Square Feet           County  \
# 30     925000         5   2.000000  2750.000000         New York
# 110   4800000         6   2.373861  3958.000000         New York
# 353    499000         2   3.000000  2184.207862         New York
# 415    235000         3   2.000000  1400.000000    Queens County
# 474    875000         2   2.000000  1214.000000         New York
# 599    299000         3   1.000000  2184.207862     Kings County
# 723    115000         3   1.000000  2184.207862    Queens County
# 1003   639888         5   3.000000  1376.000000         New York
# 1021   445000         3   2.000000  2184.207862    Queens County
# 1065   509000         3   1.000000  2184.207862    Queens County
# 1384   499900         3   1.000000  1040.000000         New York
# 1411  2900000         5   2.373861  6707.000000         New York
# 2004   270000         3   2.373861  1158.000000         New York
# 2073   430000         3   1.000000  2184.207862  New York County
# 2164   239000         1   1.000000  2184.207862    Queens County
# 2658   999000         2   2.000000  1187.000000    Queens County
# 2746  1275000         4   2.373861  2184.207862         New York
# 2905   278000         1   1.000000  2184.207862    Queens County
# 3268   248000         1   1.000000   800.000000    Queens County
# 3359   550000         2   1.000000  2184.207862  New York County
# 3385  2795000         3   3.000000  1689.000000  New York County
# 3503   515000         2   2.000000  1200.000000     Kings County
# 3578   579000         3   2.000000  2184.207862         New York
# 3607   888000         3   2.000000  1700.000000     Kings County
# 3642   771770         2   2.000000   710.000000    Queens County
# 3825   899000         2   2.000000  1056.000000         New York
# 3860   358000         3   1.000000  2184.207862    Queens County
# 3862   760000         1   1.000000   700.000000  New York County
# 3886   589000         3   1.000000   415.000000  New York County
# 3962  3999999         2   2.000000  1997.000000  New York County
# 4057   895000         2   1.000000  2184.207862  New York County
# 4760  2000000         8   2.373861  2184.207862         New York
# 4764   189000         3   1.000000   300.000000     Kings County
#
#               Borough          Neighborhood            Long Name  \
# 30       Bronx County                Bronx      Hollywood Avenue
# 110      Kings County             Brooklyn           83rd Street
# 353     Queens County         Saint Albans          193rd Street
# 415            Queens              Jamaica                 14350
# 474     Queens County          Little Neck           61st Avenue
# 599          Brooklyn             Brooklyn                  2212
# 723            Queens              Jamaica                 87-15
# 1003  Richmond County        Staten Island           Dover Green
# 1021           Queens             Flushing                138-10
# 1065           Queens      Jackson Heights                 91-10
# 1384  Richmond County        Staten Island           Harbor Road
# 1411  Richmond County        Staten Island        Annfield Court
# 2004     Bronx County                Bronx        Willett Avenue
# 2073         New York             New York                     2
# 2164           Queens         Forest Hills               111- 31
# 2658           Queens             Flushing                 13338
# 2746    Queens County          Floral Park          257th Street
# 2905        The Bronx          Kew Gardens                   125
# 3268           Queens             Flushing                 14220
# 3359         New York             New York                   804
# 3385         New York            Manhattan                   555
# 3503         Brooklyn             Brooklyn                  3060
# 3578    Queens County  Richmond Hill South          114th Street
# 3607         Brooklyn             Brooklyn                   956
# 3642           Queens             Flushing                134-16
# 3825     Kings County             Brooklyn   Independence Avenue
# 3860           Queens             Flushing                150-38
# 3862         New York             New York                   414
# 3886         New York             New York                   500
# 3962         New York             New York                   527
# 4057         New York            Manhattan                   365
# 4760     Kings County             Brooklyn           60th Street
# 4764         Brooklyn             Brooklyn                   460
#
#                                         Cleaned_Address Zipcode  \
# 30              543 Hollywood Ave, Bronx, NY 10465, USA   10465
# 110               1151 83rd St, Brooklyn, NY 11228, USA   11228
# 353             119-44 193rd St, Jamaica, NY 11412, USA   11412
# 415    14350 Hoover Ave Apt 307, Jamaica, NY 11435, USA   11435
# 474            244-89 61st Ave, Flushing, NY 11362, USA   11362
# 599        2212 Brigham St #3c, Brooklyn, NY 11229, USA   11229
# 723          87-15 165th St #6c, Jamaica, NY 11432, USA   11432
# 1003      226 Dover Green, Staten Island, NY 10312, USA   10312
# 1021   138-10 Franklin Ave #1g, Flushing, NY 11355, USA   11355
# 1065  91-10 34th Ave #5j, Jackson Heights, NY 11372,...   11372
# 1384        334 Harbor Rd, Staten Island, NY 10303, USA   10303
# 1411       29 Annfield Ct, Staten Island, NY 10304, USA   10304
# 2004             3780 Willett Ave, Bronx, NY 10467, USA   10467
# 2073       2 Tudor City Pl #4d, New York, NY 10017, USA   10017
# 2164  111- 31 66th Ave #2c, Forest Hills, NY 11375, USA   11375
# 2658   13338 Sanford Ave # 16b, Flushing, NY 11355, USA   11355
# 2746              87-66 257th St, Queens, NY 11001, USA   11001
# 2905         125 Queens Blvd # 10, Bronx, NY 10452, USA   11415
# 3268        14220 26th Ave #2a, Flushing, NY 11354, USA   11354
# 3359     804 W 180th St Apt 52, New York, NY 10033, USA   10033
# 3385        555 W 59th St #20b, New York, NY 10019, USA   10019
# 3503        3060 Ocean Ave #6p, Brooklyn, NY 11235, USA   11235
# 3578  103-12 114th St, South Richmond Hill, NY 11419...   11419
# 3607           956 79th St #1b, Brooklyn, NY 11228, USA   11228
# 3642      134-16 35th Ave #11d, Flushing, NY 11354, USA   11354
# 3825     1595 Independence Ave, Brooklyn, NY 11228, USA   11228
# 3860    150-38 Union Tpke #11b, Flushing, NY 11367, USA   11367
# 3862         414 W 54th St #4e, New York, NY 10019, USA   10019
# 3886        500 W 43rd St #12g, New York, NY 10036, USA   10036
# 3962         527 W 27th St #5s, New York, NY 10001, USA   10001
# 4057      365 W 20th St Apt 9b, New York, NY 10011, USA   10011
# 4760              2324 60th St, Brooklyn, NY 11204, USA   11204
# 4764      460 Ovington Ave #2h, Brooklyn, NY 11209, USA   11209
#
#            Property Type Brokerage                       Address
# 30    Multi-family home       None            543 Hollywood Ave
# 110              Pending      None                 1151 83rd St
# 353               House       None              119-44 193rd St
# 415               Co-op       None   143-50 Hoover Ave Unit 307
# 474               House       None              244-89 61st Ave
# 599               Co-op       None       2212 Brigham St Apt 3C
# 723               Co-op       None       87-15 165th St Unit 6C
# 1003  Multi-family home       None                226 Dover Grn
# 1021              Co-op       None  138-10 Franklin Ave Unit 1K
# 1065              Condo       None       91-10 34th Ave Unit 5J
# 1384              House       None                334 Harbor Rd
# 1411              House       None               29 Annfield Ct
# 2004              House       None             3780 Willett Ave
# 2073              Co-op       None          2 Tudor  Pl Apt 4OS
# 2164              Co-op       None      111-31 66th Ave Unit 2C
# 2658              Condo       None  133-38 Sanford Ave Unit 16D
# 2746              House       None               87-66 257th St
# 2905              Co-op       None       125-10  Blvd Unit 2302
# 3268              Co-op       None        142-20 26 Ave Unit 2A
# 3359              Co-op       None        804 W 180th St Apt 52
# 3385              Condo       None        555 W 59th St Apt 20B
# 3503              Co-op       None        3060 Ocean Ave Apt 6P
# 3578          Townhouse       None        103-12 114th St South
# 3607              Condo       None          956 79th St Unit 1B
# 3642              Condo       None     134-16 35th Ave Unit 11D
# 3825              House       None        1595 Independence Ave
# 3860              Condo       None   150-38 Union Tpke Unit 11B
# 3862              Condo       None         414 W 54th St Apt 4E
# 3886              Condo       None        500 W 43rd St Apt 12G
# 3962              Condo       None        527 W 27th St Unit 5S
# 4057             Pending      None         365 W 20th St Apt 9C
# 4760  Multi-family home       None                 2324 60th St
# 4764              Co-op       None      460 Ovington Ave Apt 2H

# %%
#No more null values, took all of these 33 out. May be not listed but overall will not effect data greatly.
#Renamed this to DF2

# %%
DF2= DF[DF['Brokerage'].isnull() == False]

# %%
DF2
# Out:
#           Price  Bedrooms  Bathrooms   Square Feet           County  \
# 0        315000         2   2.000000   1400.000000         New York
# 1     195000000         7  10.000000  17545.000000         New York
# 2        260000         4   2.000000   2015.000000         New York
# 3         69000         3   1.000000    445.000000         New York
# 4      55000000         7   2.373861  14175.000000         New York
# ...         ...       ...        ...           ...              ...
# 4796     599000         1   1.000000   2184.207862  New York County
# 4797     245000         1   1.000000   2184.207862         New York
# 4798    1275000         1   1.000000   2184.207862         New York
# 4799     598125         2   1.000000    655.000000    Queens County
# 4800     349000         1   1.000000    750.000000     Kings County
#
#               Borough    Neighborhood         Long Name  \
# 0           Manhattan       New York    Regis Residence
# 1     New York County       New York   West 57th Street
# 2     Richmond County  Staten Island    Sinclair Avenue
# 3     New York County      Manhattan   East 55th Street
# 4     New York County       New York   East 64th Street
# ...               ...             ...               ...
# 4796         New York      Manhattan                222
# 4797    Queens County      Rego Park         62nd Drive
# 4798  New York County       New York   West 21st Street
# 4799           Queens       Elmhurst              91-23
# 4800         Brooklyn       Brooklyn                460
#
#                                         Cleaned_Address Zipcode Property Type  \
# 0     Regis Residence, 2 E 55th St #803, New York, N...   10022        Condo
# 1                217 W 57th St, New York, NY 10019, USA   10019        Condo
# 2        620 Sinclair Ave, Staten Island, NY 10312, USA   10312        House
# 3                  2 E 55th St, New York, NY 10022, USA   10022        Condo
# 4                  5 E 64th St, New York, NY 10065, USA   10065    Townhouse
# ...                                                 ...     ...           ...
# 4796         222 E 80th St #3a, New York, NY 10075, USA   10075        Co-op
# 4797            97-40 62nd Dr, Rego Park, NY 11374, USA   11374        Co-op
# 4798             427 W 21st St, New York, NY 10011, USA   10011        Co-op
# 4799     91-23 Corona Ave. #4b, Flushing, NY 11373, USA   11373        Condo
# 4800      460 Neptune Ave #14a, Brooklyn, NY 11224, USA   11224        Co-op
#
#                                               Brokerage  \
# 0                       Douglas Elliman  -111 Fifth Ave
# 1                                               Serhant
# 2                                            Sowae Corp
# 3                                               COMPASS
# 4      Sotheby's International Realty - East Side Ma...
# ...                                                 ...
# 4796                                            COMPASS
# 4797                                Mjr Real Estate Llc
# 4798                  Douglas Elliman - 575 Madison Ave
# 4799                        E Realty International Corp
# 4800                             Nyc Realty Brokers Llc
#
#                                                 Address
# 0                                 2 E 55th St Unit 803
# 1     Central Park Tower Penthouse-217 W 57th  St Un...
# 2                                     620 Sinclair Ave
# 3                              2 E 55th St Unit 908W33
# 4                                          5 E 64th St
# ...                                                 ...
# 4796                              222 E 80th St Apt 3A
# 4797                               97-40 62 Dr Unit Lg
# 4798                               427 W 21st St Unit
# 4799                                91-23  Ave Unit 4G
# 4800                           460 Neptune Ave Apt 14O
#
# [4554 rows x 13 columns]

# %%
DF2['Bathrooms'].dtypes
# Out:
# dtype('float64')

# %%
DF2['Bedrooms'].dtypes
# Out:
# dtype('int64')

# %%
#Data types / Consistency. I would prefer if Bedrooms & Bathrooms are the same "types"
#Bathrooms should be rounded to the nearest whole number
#Similarly square feet should be rounded to whole number is best
#These are the easiest to do on Excel- save this for later

# %%
#Checking for outliers (50 bedrooms and bathrooms is suspicious)
#Explored within Excel, this is a full building with 50 rooms, 50 bathrooms. Apartment building style for sale. 
#No issues
DF2.describe()
# Out:
#               Price     Bedrooms    Bathrooms   Square Feet
# count  4.554000e+03  4554.000000  4554.000000   4554.000000
# mean   2.391341e+06     3.368906     2.382478   2179.892620
# std    3.218396e+07     2.635072     1.973988   2289.191594
# min    2.494000e+03     1.000000     0.000000    230.000000
# 25%    4.990000e+05     2.000000     1.000000   1200.000000
# 50%    8.250000e+05     3.000000     2.000000   2184.207862
# 75%    1.499000e+06     4.000000     3.000000   2184.207862
# max    2.147484e+09    50.000000    50.000000  65535.000000

# %%
#Export File
DF2.to_csv('/Users/winsontom/Desktop/Career Foundry/Cleaned_Data.csv')
