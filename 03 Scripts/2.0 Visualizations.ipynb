# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DF = pd.read_csv(r'/Users/winsontom/Desktop/Career Foundry/Final CF Immersion/02 Data/3.5 Data for Visualizations.csv')

# %%
DF
# Out:
#                                                 Address        Borough  \
# 0                                 2 E 55th St Unit 803       Manhattan
# 1     Central Park Tower Penthouse-217 W 57th  St Un...      Manhattan
# 2                                     620 Sinclair Ave   Staten Island
# 3                              2 E 55th St Unit 908W33       Manhattan
# 4                                          5 E 64th St       Manhattan
# ...                                                 ...            ...
# 4549                              222 E 80th St Apt 3A       Manhattan
# 4550                               97-40 62 Dr Unit Lg          Queens
# 4551                               427 W 21st St Unit        Manhattan
# 4552                                91-23  Ave Unit 4G          Queens
# 4553                           460 Neptune Ave Apt 14O        Brooklyn
#
#      Property Type  Bedrooms  Bathrooms     Price    Square Footage  \
# ...

# %% [markdown]
# ## Choosing Variables to explore via the business questions created

# %%
#Lets re visit what the questions are and which ones is appropriate for this visualization correlation comparison

#1. Average price of properties within a Borough?
#2. Average price of property based on Property Type
#3. Relationship between square footage and Price?
#4. Relationship between price per Square Feet & square feet  
#5. Type of property and brokerage?
#6. Zipcode and price per square feet?
#7. Zipcode and listing price?

# %%
#Specific NUMERIC Variables to look up in the correlation heat map:

# Price, Bedrooms, Bathroom, Square Footage, Price per Square Feet)

#Other factors can't be measured as not numeric and not truly relevant to these correlations.
#Will find further relationships such as Price and Zicode later on but this currnet heatmap does not suit this

# %%
DF.columns
# Out:
# Index(['Address', 'Borough', 'Property Type', 'Bedrooms', 'Bathrooms',
#        ' Price ', ' Square Footage', 'Price Per Square Feet (Rounded)',
#        'Exact Address', 'Neighborhood', 'County', 'Zipcode', 'Brokerage'],
#       dtype='object')

# %%
DF.dtypes
# Out:
# Address                            object
# Borough                            object
# Property Type                      object
# Bedrooms                            int64
# Bathrooms                           int64
#  Price                              int64
#  Square Footage                     int64
# Price Per Square Feet (Rounded)     int64
# Exact Address                      object
# Neighborhood                       object
# County                             object
# Zipcode                             int64
# Brokerage                          object
# dtype: object

# %%
DF.columns
# Out:
# Index(['Address', 'Borough', 'Property Type', 'Bedrooms', 'Bathrooms',
#        ' Price ', ' Square Footage', 'Price Per Square Feet (Rounded)',
#        'Exact Address', 'Neighborhood', 'County', 'Zipcode', 'Brokerage'],
#       dtype='object')

# %% [markdown]
# ## Heatmap

# %%
DF2 = DF[[' Price ', 'Bedrooms','Bathrooms',' Square Footage','Price Per Square Feet (Rounded)']]

# %%
DF2.head(1)
# Out:
#     Price   Bedrooms  Bathrooms   Square Footage  \
# 0   315000         2          2             1400
#
#    Price Per Square Feet (Rounded)
# 0                              225

# %%
corr = DF2.corr()
corr
# Out:
#                                    Price   Bedrooms  Bathrooms  \
#  Price                           1.000000  0.051775   0.077728
# Bedrooms                         0.051775  1.000000   0.773950
# Bathrooms                        0.077728  0.773950   1.000000
#  Square Footage                  0.115805  0.442598   0.500975
# Price Per Square Feet (Rounded)  0.963647  0.050464   0.101468
#
#                                   Square Footage  \
#  Price                                  0.115805
# Bedrooms                                0.442598
# Bathrooms                               0.500975
#  Square Footage                         1.000000
# Price Per Square Feet (Rounded)         0.075873
#
#                                  Price Per Square Feet (Rounded)
#  Price                                                  0.963647
# Bedrooms                                                0.050464
# Bathrooms                                               0.101468
# ...

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
# Save figure
plt.matshow(DF2.corr())
plt.savefig("out.png")

# %%
#What the coefficients in the plot mean in terms of the relationships between the variables.

# %%
# Reminder that 0 = Black = no correlation ; 1.0 = Peach = 100% correlation. 

# If we look one column at a time, price has minimal correlation with bedrooms, bathrooms, and square footage.
# Price per Square Feet (Rounded) is directly corrleated with square feet.
# This conclusion of price may be due to location being a bigger variable than bedrooms/bathrooms.

#Bedrooms does have a medium correlation with square footage. 
#Bedrooms does have a stronger correlation with Bathrooms.
#Bedrooms and Price pretty much not correlated

#Bathrooms column, have a medium correlation with square footage
#Bathrooms column, have a medium correlation with bedrooms

#Square footage column, medium correlation with bedrooms and bathrooms
#Square footage column, medium correlation with bedrooms and bathrooms

#Price per square feet and Price has correlation.

# %% [markdown]
# ## Scatterplots

# %%
#Identifying a linear or Non Linear Trend

# %%
# Create a scatterplot for the "house age" and "price per unit" columns in seaborn

sns.lmplot(x = ' Square Footage', y = ' Price ', data = DF2)
# Out:
# /Users/winsontom/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#There is a small positive correlation between square Footage and price. 
#I had initially predicted a strong correlation meaning if size gets bigger, price goes up.
#However we have found this to not be directly true. That there are a vareity of prices for similar sizes.
# That you can have a 5,000 square feet home that cost more than a 10,0000 square feet home

# %% [markdown]
# ## Further Data Cleaning (outliers)

# %%
# Suspecting some of these properties are inaccurately priced, the numbers seem too high on some

# %%
DF2.describe()
# Out:
#              Price      Bedrooms    Bathrooms   Square Footage  \
# count  4.554000e+03  4554.000000  4554.000000      4554.000000
# mean   2.391341e+06     3.368906     2.359245      2179.823013
# std    3.218396e+07     2.635072     1.976152      2289.191465
# min    2.494000e+03     1.000000     0.000000       230.000000
# 25%    4.990000e+05     2.000000     1.000000      1200.000000
# 50%    8.250000e+05     3.000000     2.000000      2184.000000
# 75%    1.499000e+06     4.000000     3.000000      2184.000000
# max    2.147484e+09    50.000000    50.000000     65535.000000
#
#        Price Per Square Feet (Rounded)
# count                      4554.000000
# mean                        827.441809
# std                        3384.159260
# min                           1.000000
# 25%                         325.250000
# 50%                         492.000000
# 75%                         821.750000
# max                      214748.000000

# %%
#Some of these numbers look off.

#Only 6659-6675 Amboy Rd is off as that is over 1 billion dollar home, which it is not. 
#Its a multi million dollar home, making edits

# %% [markdown]
# ## Further cleaned data - Property types, Outliers, Blanks

# %%
DF3 = pd.read_csv(r'/Users/winsontom/Desktop/Career Foundry/Final CF Immersion/02 Data/4.0 Cleaned Further.csv')

# %%
DF3.describe()
# Out:
#           Bedrooms    Bathrooms         Price  Square Footage  \
# count  4552.000000  4552.000000  4.552000e+03     4552.000000
# mean      3.369069     2.359402  1.920558e+06     2180.217267
# std       2.635640     1.976572  4.996060e+06     2289.539117
# min       1.000000     0.000000  2.494000e+03      230.000000
# 25%       2.000000     1.000000  4.990000e+05     1200.000000
# 50%       3.000000     2.000000  8.250000e+05     2184.000000
# 75%       4.000000     3.000000  1.499000e+06     2184.000000
# max      50.000000    50.000000  1.950000e+08    65535.000000
#
#        Price Per Square Feet       Zipcode
# count            4552.000000   4552.000000
# mean              780.208640  10756.833919
# std              1183.217343    573.497613
# min                 1.140000  10001.000000
# 25%               325.090000  10075.000000
# 50%               492.125000  11103.000000
# 75%               819.217500  11236.000000
# max             27472.530000  11697.000000

# %%
DF3.head(5)
# Out:
#                                              Address        Borough  \
# 0                              2 E 55th St Unit 803       Manhattan
# 1  Central Park Tower Penthouse-217 W 57th  St Un...      Manhattan
# 2                                  620 Sinclair Ave   Staten Island
# 3                           2 E 55th St Unit 908W33       Manhattan
# 4                                       5 E 64th St       Manhattan
#
#   Property Type  Bedrooms  Bathrooms      Price  Square Footage  \
# 0         Condo         2          2     315000            1400
# 1         Condo         7         10  195000000           17545
# 2        House          4          2     260000            2015
# 3         Condo         3          1      69000             445
# 4    Townhouse          7          2   55000000           14175
#
#    Price Per Square Feet                                      Exact Address  \
# 0                 225.00  Regis Residence, 2 E 55th St #803, New York, N...
# ...

# %%
DF3.columns
# Out:
# Index(['Address', 'Borough', 'Property Type', 'Bedrooms', 'Bathrooms', 'Price',
#        'Square Footage', 'Price Per Square Feet', 'Exact Address',
#        'Neighborhood', 'County', 'Zipcode', 'Brokerage'],
#       dtype='object')

# %%
#Identifying correlation between bedrooms and bathrooms. 
#As Bedrooms go up generally the bathrooms go up as well.
#On the lower end of the bedrooms, there are a variety of bathroom #s

sns.lmplot(x = 'Bedrooms', y = 'Bathrooms', data = DF3)
# Out:
# /Users/winsontom/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Pair Plot

# %%
sns.set_style('darkgrid')

# %%
sns.pairplot(DF3);
# Out:
# /Users/winsontom/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/winsontom/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/winsontom/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#Categorial values include: Bedrooms & Zipcode, Bathroom & Zipcode, Price & Zip code, Price per Square Feet & Zipcode

#I would like to furhter explore Price & Zipcode as well as Price per Square Feet & Zipcode
#This is a "real world" question. How much are average prices in this zip code? How much is an average price per square feet in this zipcode?
#As location is usually the primary factor differentiating price, price per zipcodes does matter.

# %%
#Visible Trends: (Scatter plot data is moving up or down)
#Price per Square Feet, Price
#Bathrooms, Bedrooms

#Everything else seems to be more seperate data than correlating data
